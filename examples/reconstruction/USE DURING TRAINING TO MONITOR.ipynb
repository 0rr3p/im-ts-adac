# %%
# !tensorboard --logdir="C:\\Users\\Carlo\\time-series-autoencoder\\examples\\reconstruction\\multirun"

# %%
# Out:
# "diff" non Š riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.
